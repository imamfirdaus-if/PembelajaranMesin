# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/imamfirdaus-if/PembelajaranMesin/main/Quiz%202/russia_losses_equipment.csv'
df = pd.read_csv(url)

# %%
df.head()
# Out:
#          date  day  aircraft  helicopter  tank  APC  field artillery  BUK  \
# 0  2022-02-26    3        27          26   146  706               49    1
# 1  2022-02-28    5        29          29   150  816               74    1
# 2  2022-03-01    6        29          29   198  846               77    1
# 3  2022-03-02    7        30          31   211  862               85    1
# 4  2022-03-03    8        30          31   217  900               90    1
#
#    MRL  military auto  fuel tank  drone  naval ship  anti-aircraft warfare
# 0    4             30         60      2           2                      0
# 1   21            291         60      3           2                      5
# 2   24            305         60      3           2                      7
# 3   40            355         60      3           2                      9
# 4   42            374         60      3           2                     11

# %%
print(df.dtypes)
# Out:
# date                     object
# day                       int64
# aircraft                  int64
# helicopter                int64
# tank                      int64
# APC                       int64
# field artillery           int64
# BUK                       int64
# MRL                       int64
# military auto             int64
# fuel tank                 int64
# drone                     int64
# naval ship                int64
# anti-aircraft warfare     int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   13 non-null     object
#  1   day                    13 non-null     int64
#  2   aircraft               13 non-null     int64
#  3   helicopter             13 non-null     int64
#  4   tank                   13 non-null     int64
#  5   APC                    13 non-null     int64
#  6   field artillery        13 non-null     int64
#  7   BUK                    13 non-null     int64
#  8   MRL                    13 non-null     int64
#  9   military auto          13 non-null     int64
#  10  fuel tank              13 non-null     int64
#  11  drone                  13 non-null     int64
#  12  naval ship             13 non-null     int64
#  13  anti-aircraft warfare  13 non-null     int64
# dtypes: int64(13), object(1)
# memory usage: 1.5+ KB

# %%
df.describe()
# Out:
#              day   aircraft  helicopter        tank          APC  \
# count  13.000000  13.000000   13.000000   13.000000    13.000000
# mean    9.923077  39.230769   51.076923  255.769231   951.846154
# std     4.030334  10.084260   23.581283   67.092168   127.254893
# min     3.000000  27.000000   26.000000  146.000000   706.000000
# 25%     7.000000  30.000000   31.000000  211.000000   862.000000
# 50%    10.000000  39.000000   40.000000  269.000000   945.000000
# 75%    13.000000  48.000000   80.000000  303.000000  1036.000000
# max    16.000000  57.000000   83.000000  353.000000  1165.000000
#
#        field artillery   BUK        MRL  military auto  fuel tank      drone  \
# count        13.000000  13.0  13.000000      13.000000       13.0  13.000000
# mean         99.923077   1.0  42.846154     393.000000       60.0   4.538462
# std          23.282545   0.0  16.592399     134.824577        0.0   2.066212
# ...

# %%
df.count()
# Out:
# date                     13
# day                      13
# aircraft                 13
# helicopter               13
# tank                     13
# APC                      13
# field artillery          13
# BUK                      13
# MRL                      13
# military auto            13
# fuel tank                13
# drone                    13
# naval ship               13
# anti-aircraft warfare    13
# dtype: int64

# %%
df.describe(include='all')
# Out:
#               date        day   aircraft  helicopter        tank          APC  \
# count           13  13.000000  13.000000   13.000000   13.000000    13.000000
# unique          13        NaN        NaN         NaN         NaN          NaN
# top     2022-02-26        NaN        NaN         NaN         NaN          NaN
# freq             1        NaN        NaN         NaN         NaN          NaN
# mean           NaN   9.923077  39.230769   51.076923  255.769231   951.846154
# std            NaN   4.030334  10.084260   23.581283   67.092168   127.254893
# min            NaN   3.000000  27.000000   26.000000  146.000000   706.000000
# 25%            NaN   7.000000  30.000000   31.000000  211.000000   862.000000
# 50%            NaN  10.000000  39.000000   40.000000  269.000000   945.000000
# 75%            NaN  13.000000  48.000000   80.000000  303.000000  1036.000000
# max            NaN  16.000000  57.000000   83.000000  353.000000  1165.000000
#
# ...

# %%
df.fillna(0)
# Out:
#           date  day  aircraft  helicopter  tank   APC  field artillery  BUK  \
# 0   2022-02-26    3        27          26   146   706               49    1
# 1   2022-02-28    5        29          29   150   816               74    1
# 2   2022-03-01    6        29          29   198   846               77    1
# 3   2022-03-02    7        30          31   211   862               85    1
# 4   2022-03-03    8        30          31   217   900               90    1
# 5   2022-03-04    9        33          37   251   939              105    1
# 6   2022-03-05   10        39          40   269   945              105    1
# 7   2022-03-06   11        44          48   285   985              109    1
# 8   2022-03-07   12        46          68   290   999              117    1
# 9   2022-03-08   13        48          80   303  1036              120    1
# 10  2022-03-09   14        49          81   317  1070              120    1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   13 non-null     object
#  1   day                    13 non-null     int64
#  2   aircraft               13 non-null     int64
#  3   helicopter             13 non-null     int64
#  4   tank                   13 non-null     int64
#  5   APC                    13 non-null     int64
#  6   field artillery        13 non-null     int64
#  7   BUK                    13 non-null     int64
#  8   MRL                    13 non-null     int64
#  9   military auto          13 non-null     int64
#  10  fuel tank              13 non-null     int64
#  11  drone                  13 non-null     int64
#  12  naval ship             13 non-null     int64
#  13  anti-aircraft warfare  13 non-null     int64
# dtypes: int64(13), object(1)
# memory usage: 1.5+ KB

# %%
df['day']=df['day'].fillna(0)
df['aircraft']=df['aircraft'].fillna(0)
df['helicopter']=df['helicopter'].fillna(0)
df['tank']=df['tank'].fillna(0)
df['APC']=df['APC'].fillna(0)
df['field artillery']=df['field artillery'].fillna(0)
df['BUK']=df['BUK'].fillna(0)
df['MRL']=df['MRL'].fillna(0)
df['military auto']=df['military auto'].fillna(0)
df['fuel tank']=df['fuel tank'].fillna(0)
df['drone']=df['drone'].fillna(0)
df['naval ship']=df['naval ship'].fillna(0)
df['anti-aircraft warfare']=df['anti-aircraft warfare'].fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   date                   13 non-null     object
#  1   day                    13 non-null     int64
#  2   aircraft               13 non-null     int64
#  3   helicopter             13 non-null     int64
#  4   tank                   13 non-null     int64
#  5   APC                    13 non-null     int64
#  6   field artillery        13 non-null     int64
#  7   BUK                    13 non-null     int64
#  8   MRL                    13 non-null     int64
#  9   military auto          13 non-null     int64
#  10  fuel tank              13 non-null     int64
#  11  drone                  13 non-null     int64
#  12  naval ship             13 non-null     int64
#  13  anti-aircraft warfare  13 non-null     int64
# dtypes: int64(13), object(1)
# memory usage: 1.5+ KB

# %%
df.describe(include='all')
# Out:
#               date        day   aircraft  helicopter        tank          APC  \
# count           13  13.000000  13.000000   13.000000   13.000000    13.000000
# unique          13        NaN        NaN         NaN         NaN          NaN
# top     2022-02-26        NaN        NaN         NaN         NaN          NaN
# freq             1        NaN        NaN         NaN         NaN          NaN
# mean           NaN   9.923077  39.230769   51.076923  255.769231   951.846154
# std            NaN   4.030334  10.084260   23.581283   67.092168   127.254893
# min            NaN   3.000000  27.000000   26.000000  146.000000   706.000000
# 25%            NaN   7.000000  30.000000   31.000000  211.000000   862.000000
# 50%            NaN  10.000000  39.000000   40.000000  269.000000   945.000000
# 75%            NaN  13.000000  48.000000   80.000000  303.000000  1036.000000
# max            NaN  16.000000  57.000000   83.000000  353.000000  1165.000000
#
# ...

# %%
df.corr()
# Out:
#                             day  aircraft  helicopter      tank       APC  \
# day                    1.000000  0.962100    0.935634  0.988882  0.992248
# aircraft               0.962100  1.000000    0.954854  0.948243  0.943062
# helicopter             0.935634  0.954854    1.000000  0.901914  0.906836
# tank                   0.988882  0.948243    0.901914  1.000000  0.977266
# APC                    0.992248  0.943062    0.906836  0.977266  1.000000
# field artillery        0.965264  0.894864    0.859099  0.962702  0.963887
# BUK                         NaN       NaN         NaN       NaN       NaN
# MRL                    0.909494  0.798590    0.749089  0.919296  0.913730
# military auto          0.916165  0.816352    0.766119  0.901333  0.942759
# fuel tank                   NaN       NaN         NaN       NaN       NaN
# drone                  0.896009  0.913412    0.979090  0.850976  0.869059
# naval ship             0.832363  0.862423    0.960397  0.782851  0.796333
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

korelasi = df.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(korelasi[(korelasi >= 0.5) | (korelasi <= -0.4)], cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1, 
            annot=True, annot_kws={"size": 8}, square=True).set_title('Korelasi Antar Variabel')
plt.show()

# %%
#Perbandingan kehilangan tank dengan helikopter
equipment_total = df.groupby("date")["tank"].sum().sort_values()
equipment_total.plot(kind="barh", fontsize=10, figsize=(8,40), title='Jumlah Tank yang rusak')
plt.show()

equipment_total = df.groupby("date")["helicopter"].sum().sort_values()
equipment_total.plot(kind="barh", fontsize=10, figsize=(8,40), title='Jumlah Helicopter yang rusak')
plt.show()

# %%
sns.boxplot(df['helicopter'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Scatter plot
fig, ax = plt.subplots(figsize = (10,10))
ax.scatter(df['tank'], df['helicopter'])

# x-axis label
ax.set_xlabel('Total Tank yang rusak')
 
# y-axis label
ax.set_ylabel('Total Helicopter yang rusak')
plt.show()
