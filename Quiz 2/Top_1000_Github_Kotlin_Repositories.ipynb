# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/imamfirdaus-if/PembelajaranMesin/main/Quiz%202/Kotlin.json'
df = pd.read_json(url)

# %%
df.head
# Out:
# <bound method NDFrame.head of             id                     repo_name  \
# 0     14098069  free-programming-books-zh_CN
# 1      5152285                        okhttp
# 2      3432266                        kotlin
# 3     34824499                    leakcanary
# 4     18347476                       iosched
# ..         ...                           ...
# 995  423815133   Android-Kotlin-Fundamentals
# 996  385703291                     Dota-Info
# 997  152759230                  MagicCamera3
# 998  243047314                           zoe
# 999  121126549                        SwayDB
#
#                                   full_name  \
# 0    justjavac/free-programming-books-zh_CN
# 1                             square/okhttp
# 2                          JetBrains/kotlin
# 3                         square/leakcanary
# 4                            google/iosched
# ..                                      ...
# 995   serkanalc/Android-Kotlin-Fundamentals
# ...

# %%
print(df.dtypes)
# Out:
# id              int64
# repo_name      object
# full_name      object
# description    object
# created        object
# language       object
# type           object
# username       object
# stars           int64
# forks           int64
# subscribers     int64
# open_issues     int64
# topics         object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           1000 non-null   int64
#  1   repo_name    1000 non-null   object
#  2   full_name    1000 non-null   object
#  3   description  988 non-null    object
#  4   created      1000 non-null   object
#  5   language     965 non-null    object
#  6   type         1000 non-null   object
#  7   username     1000 non-null   object
#  8   stars        1000 non-null   int64
#  9   forks        1000 non-null   int64
#  10  subscribers  1000 non-null   int64
#  11  open_issues  1000 non-null   int64
#  12  topics       1000 non-null   object
# dtypes: int64(5), object(8)
# memory usage: 101.7+ KB

# %%
df.describe()
# Out:
#                  id         stars         forks  subscribers  open_issues
# count  1.000000e+03   1000.000000   1000.000000  1000.000000  1000.000000
# mean   1.385211e+08   1435.921000    246.999000    55.233000    40.510000
# std    9.292108e+07   3964.936486    954.661583   215.540958    96.346638
# min    2.297380e+05    252.000000      8.000000     2.000000     0.000000
# 25%    6.650238e+07    358.000000     41.000000    12.000000     3.000000
# 50%    1.183327e+08    568.500000     78.000000    22.000000    10.000000
# 75%    1.956167e+08   1142.000000    186.250000    46.000000    36.250000
# max    4.586448e+08  87779.000000  25110.000000  5921.000000   986.000000

# %%
df.count()
# Out:
# id             1000
# repo_name      1000
# full_name      1000
# description     988
# created        1000
# language        965
# type           1000
# username       1000
# stars          1000
# forks          1000
# subscribers    1000
# open_issues    1000
# topics         1000
# dtype: int64

# %%
df.describe(include='all')
# Out:
#                   id repo_name            full_name  \
# count   1.000000e+03      1000                 1000
# unique           NaN       971                  984
# top              NaN   android  nitrico/LastAdapter
# freq             NaN         4                    2
# mean    1.385211e+08       NaN                  NaN
# std     9.292108e+07       NaN                  NaN
# min     2.297380e+05       NaN                  NaN
# 25%     6.650238e+07       NaN                  NaN
# 50%     1.183327e+08       NaN                  NaN
# 75%     1.956167e+08       NaN                  NaN
# max     4.586448e+08       NaN                  NaN
#
#                                               description  \
# count                                                 988
# unique                                                970
# top     A Kotlin DSL and Java/Kotlin builder API for c...
# freq                                                    2
# ...

# %%
df.fillna(0)
# Out:
#             id                     repo_name  \
# 0     14098069  free-programming-books-zh_CN
# 1      5152285                        okhttp
# 2      3432266                        kotlin
# 3     34824499                    leakcanary
# 4     18347476                       iosched
# ..         ...                           ...
# 995  423815133   Android-Kotlin-Fundamentals
# 996  385703291                     Dota-Info
# 997  152759230                  MagicCamera3
# 998  243047314                           zoe
# 999  121126549                        SwayDB
#
#                                   full_name  \
# 0    justjavac/free-programming-books-zh_CN
# 1                             square/okhttp
# 2                          JetBrains/kotlin
# 3                         square/leakcanary
# 4                            google/iosched
# ..                                      ...
# 995   serkanalc/Android-Kotlin-Fundamentals
# 996                   mitchtabian/Dota-Info
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           1000 non-null   int64
#  1   repo_name    1000 non-null   object
#  2   full_name    1000 non-null   object
#  3   description  988 non-null    object
#  4   created      1000 non-null   object
#  5   language     965 non-null    object
#  6   type         1000 non-null   object
#  7   username     1000 non-null   object
#  8   stars        1000 non-null   int64
#  9   forks        1000 non-null   int64
#  10  subscribers  1000 non-null   int64
#  11  open_issues  1000 non-null   int64
#  12  topics       1000 non-null   object
# dtypes: int64(5), object(8)
# memory usage: 101.7+ KB

# %%
df['id']=df['id'].fillna(0)
df['stars']=df['stars'].fillna(0)
df['forks']=df['forks'].fillna(0)
df['subscribers']=df['subscribers'].fillna(0)
df['open_issues']=df['open_issues'].fillna(0)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           1000 non-null   int64
#  1   repo_name    1000 non-null   object
#  2   full_name    1000 non-null   object
#  3   description  988 non-null    object
#  4   created      1000 non-null   object
#  5   language     965 non-null    object
#  6   type         1000 non-null   object
#  7   username     1000 non-null   object
#  8   stars        1000 non-null   int64
#  9   forks        1000 non-null   int64
#  10  subscribers  1000 non-null   int64
#  11  open_issues  1000 non-null   int64
#  12  topics       1000 non-null   object
# dtypes: int64(5), object(8)
# memory usage: 101.7+ KB

# %%
df.describe(include='all')
# Out:
#                   id repo_name            full_name  \
# count   1.000000e+03      1000                 1000
# unique           NaN       971                  984
# top              NaN   android  nitrico/LastAdapter
# freq             NaN         4                    2
# mean    1.385211e+08       NaN                  NaN
# std     9.292108e+07       NaN                  NaN
# min     2.297380e+05       NaN                  NaN
# 25%     6.650238e+07       NaN                  NaN
# 50%     1.183327e+08       NaN                  NaN
# 75%     1.956167e+08       NaN                  NaN
# max     4.586448e+08       NaN                  NaN
#
#                                               description  \
# count                                                 988
# unique                                                970
# top     A Kotlin DSL and Java/Kotlin builder API for c...
# freq                                                    2
# ...

# %%
df.corr()
# Out:
#                    id     stars     forks  subscribers  open_issues
# id           1.000000 -0.180014 -0.167352    -0.165521    -0.177518
# stars       -0.180014  1.000000  0.895116     0.924637     0.211634
# forks       -0.167352  0.895116  1.000000     0.959963     0.147092
# subscribers -0.165521  0.924637  0.959963     1.000000     0.143519
# open_issues -0.177518  0.211634  0.147092     0.143519     1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

korelasi = df.corr()
plt.figure(figsize=(15, 10))
sns.heatmap(korelasi[(korelasi >= 0.5) | (korelasi <= -0.4)], cmap='viridis', vmax=1.0, vmin=-1.0, linewidths=0.1, 
            annot=True, annot_kws={"size": 8}, square=True).set_title('Korelasi Antar Variabel')
plt.show()

# %%
#Perbandingan top 1000 user github berdasarkan jumlah subsribers dan jumlah stars
git_total = df.groupby("username")["subscribers"].sum().sort_values()
git_total.plot(kind="barh", fontsize=10, figsize=(8,40), title='Jumlah subscribers')
plt.show()

git_total = df.groupby("username")["stars"].sum().sort_values()
git_total.plot(kind="barh", fontsize=10, figsize=(8,40), title='Jumlah stars')
plt.show()

# %%
sns.boxplot(df['stars'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
# Diagram tebar Top 1000 Github Repositories berdasarkan subscribers dan stars
fig, ax = plt.subplots(figsize = (10,10))
ax.scatter(df['subscribers'], df['stars'])

# x-axis label
ax.set_xlabel('Total subscribers')
 
# y-axis label
ax.set_ylabel('Total stars')
plt.show()
